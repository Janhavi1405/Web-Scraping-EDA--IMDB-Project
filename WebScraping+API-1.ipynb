# %%
# Imports
import requests
import pandas as pd
import time
import random
import re
import concurrent.futures
from bs4 import BeautifulSoup

# %% [markdown]
# ## Web Scraping

# %% [markdown]
# ### Web Scraping using OMDb

# %%
#API Base Settings
API_KEY = "93a674ac"  # Your provided OMDb API key
OMDB_BASE_URL = "http://www.omdbapi.com/"

# %%
#function to get movie data from OMDb
def fetch_movie_data(title):
    params = {
        "t": title,
        "apikey": API_KEY
    }
    
    try:
        response = requests.get(OMDB_BASE_URL, params=params)
        if response.status_code == 200:
            data = response.json()
            if data.get("Response") == "True":
                return {
                    "Title": data.get("Title"),
                    "Year": data.get("Year"),
                    "Rated": data.get("Rated"),
                    "Runtime": data.get("Runtime"),
                    "Genre": data.get("Genre"),
                    "Director": data.get("Director"),
                    "Stars": data.get("Actors"),
                    "IMDb_Rating": data.get("imdbRating"),
                    "Metascore": data.get("Metascore"),
                    "Votes": data.get("imdbVotes"),
                    "Gross": data.get("BoxOffice"),
                    "Plot": data.get("Plot")
                }
            else:
                print(f"Movie not found: {title}")
        else:
            print(f"Request failed for: {title}")
    except Exception as e:
        print(f"Error fetching {title}: {e}")
    
    return None

# %% [markdown]
# ### Web Scraping Letterboxd to get the list of the top 500 movies in history

# %%
#Base URL
base_url = "https://letterboxd.com/reelstats/list/the-500-greatest-movies-of-all-time-according/detail/page/{}/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"
}

top_500_titles = []

# Loop through pages 1 to 5
for page_num in range(1, 6):
    url = base_url.format(page_num)
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Extract movie slugs
    movies = soup.select("ul.poster-list li div.poster")
    
    for movie in movies:
        title = movie.get("data-target-link", None)
        if title:
            parts = title.strip('/').split('/')
            if len(parts) >= 2:
                movie_slug = parts[1]
                movie_clean = movie_slug.replace('-', ' ').title()
                top_500_titles.append(movie_clean)
    
    print(f"✅ Scraped {len(movies)} movie titles from page {page_num}")

print(f"🎯 Total scraped: {len(top_500_titles)} movies")
print(top_500_titles[:10])
# Out:
# ✅ Scraped 100 movie titles from page 1
# ✅ Scraped 100 movie titles from page 2
# ✅ Scraped 100 movie titles from page 3
# ✅ Scraped 100 movie titles from page 4
# ✅ Scraped 100 movie titles from page 5
# 🎯 Total scraped: 500 movies
# ['The Godfather', 'The Godfather Part Ii', 'Seven Samurai', '12 Angry Men', 'City Lights', 'The Good The Bad And The Ugly', 'The Shawshank Redemption', 'Psycho', 'Modern Times', 'Schindlers List']

# %%
print(top_500_titles[101:200])
# Out:
# ['Three Colours Red', 'Yojimbo', 'Back To The Future', 'My Neighbor Totoro', 'In The Mood For Love', 'Princess Mononoke', 'Saving Private Ryan', 'Cinema Paradiso', 'La Jetee', 'The Wages Of Fear', 'Das Boot', 'Fight Club', 'Nights Of Cabiria', 'La Strada', 'Amadeus', 'Forrest Gump', 'Spider Man Into The Spider Verse', 'The Lion King', 'Inception', 'Whiplash 2014', 'The Shop Around The Corner', 'Rififi', 'Umberto D', 'Army Of Shadows', 'Blade Runner', 'Samurai Rebellion', 'Close Up', 'The Circus', 'Raiders Of The Lost Ark', 'Grand Illusion', 'A Clockwork Orange', 'Eternal Sunshine Of The Spotless Mind', 'A Woman Under The Influence', 'The Cranes Are Flying', 'Yi Yi', 'To Kill A Mockingbird', 'The Matrix', 'The Sting', 'The Mother And The Whore', 'Se7En', 'Early Summer', 'Werckmeister Harmonies', 'Coco 2017', 'Toy Story', 'It Happened One Night', 'Reservoir Dogs', 'Unforgiven', 'The Deer Hunter', 'The Young And The Damned', 'The Best Years Of Our Lives', 'The Leopard', 'Time Of The Gypsies', 'Ali Fear Eats The Soul', 'Raise The Red Lantern', 'Terminator 2 Judgment Day', 'The Shining', 'Portrait Of A Lady On Fire', 'Viridiana', 'Greed', 'Gone With The Wind', 'There Will Be Blood', 'La Confidential', 'Paris Texas', 'Throne Of Blood', 'Toy Story 3', 'Memento', 'On The Waterfront', 'A Trip To The Moon', 'The Rules Of The Game', 'Red Beard', 'The Grapes Of Wrath', 'Au Hasard Balthazar', 'Autumn Sonata', 'Annie Hall', 'The Conformist', 'Rocco And His Brothers', 'Dersu Uzala', 'Cool Hand Luke', 'Monty Python And The Holy Grail', 'Le Samourai', 'Aliens', 'Playtime', 'The Bridge On The River Kwai', 'The Red Shoes', 'American Beauty', 'To Live', 'Battleship Potemkin', 'Day Of Wrath', 'All Quiet On The Western Front', 'Its Such A Beautiful Day', 'Full Metal Jacket', 'The Cabinet Of Dr Caligari 1920', 'Kes', 'The Usual Suspects', 'The Cameraman', 'Aparajito', 'The Elephant Man', 'Rebecca', 'Make Way For Tomorrow']

# %% [markdown]
# ### Using OMDb's API to create the dataset

# %%
API_KEY = "93a674ac" 
OMDB_BASE_URL = "http://www.omdbapi.com/"

#to fetch data for one movie
def fetch_movie_data(title):
    params = {
        "t": title,
        "apikey": API_KEY
    }
    
    try:
        response = requests.get(OMDB_BASE_URL, params=params)
        if response.status_code == 200:
            data = response.json()
            if data.get("Response") == "True":
                return {
                    "Title": data.get("Title"),
                    "Year": data.get("Year"),
                    "Rated": data.get("Rated"),
                    "Runtime": data.get("Runtime"),
                    "Genre": data.get("Genre"),
                    "Director": data.get("Director"),
                    "Stars": data.get("Actors"),
                    "IMDb_Rating": data.get("imdbRating"),
                    "Metascore": data.get("Metascore"),
                    "Votes": data.get("imdbVotes"),
                    "Gross": data.get("BoxOffice"),
                    "Plot": data.get("Plot")
                }
            else:
                print(f"❗ Movie not found: {title}")
        else:
            print(f"❗ Request failed for: {title}")
    except Exception as e:
        print(f"❗ Error fetching {title}: {e}")
    
    return None

#for all movie metadata
movie_data = []

#manual corrections in movie titles
title_corrections = {
    "Schindlers List": "Schindler's List",
    "One Flew Over The Cuckoos Nest": "One Flew Over the Cuckoo's Nest",
    "Sunrise A Song Of Two Humans": "Sunrise: A Song of Two Humans",
    "Its A Wonderful Life": "It's a Wonderful Life",
    "8 Half": "8½",
    "Apur Sansar": "The World of Apu",
    "Witness For The Prosecution 1957": "Witness for the Prosecution",
    "Walle": "WALL·E",
    "Three Colours Red": "Three Colors: Red",
    "Coco 2017": "Coco",
    "Its Such A Beautiful Day": "It's Such a Beautiful Day",
    "The Cabinet Of Dr Caligari 1920": "The Cabinet of Dr. Caligari",
    "Underground 1995": "Underground",
    "Ivans Childhood": "Ivan's Childhood",
    "Faust 1926": "Faust",
    "Diabolique 1955": "Les Diaboliques",
    "Latalante": "L'Atalante",
    "Forbidden Games 1952": "Forbidden Games",
    "Howls Moving Castle": "Howl's Moving Castle",
    "Rosemarys Baby": "Rosemary's Baby",
    "Lavventura": "L'Avventura",
    "Three Colours Blue": "Three Colors: Blue",
    "Inside Out 2015": "Inside Out",
    "Where Is The Friends House": "Where Is My Friend's House?",
    "Nostalgia 1983": "Nostalghia",
    "Leclisse": "L'Eclisse",
    "In The Name Of The Father 1993": "In the Name of the Father",
    "The Maltese Falcon 1941": "The Maltese Falcon",
    "Pans Labyrinth": "Pan's Labyrinth",
    "Ben Hur 1959": "Ben-Hur",
    "Fireworks 1997": "Hana-bi",
    "My Night At Mauds": "My Night at Maud's",
    "Marriage Story 2019": "Marriage Story",
    "Intolerance Loves Struggle Throughout The Ages": "Intolerance: Love's Struggle Throughout the Ages",
    "My Left Foot The Story Of Christy Brown": "My Left Foot",
    "The Kings Speech": "The King's Speech",
    "Whos Afraid Of Virginia Woolf": "Who's Afraid of Virginia Woolf?",
    "The Gospel According To Matthew 1964": "The Gospel According to St. Matthew",
    "Kikis Delivery Service": "Kiki's Delivery Service",
    "All The Presidents Men": "All the President's Men",
    "Mommy 2014": "Mommy",
    "A Hard Days Night": "A Hard Day's Night",
    "Duck Soup 1933": "Duck Soup",
    "Carlitos Way": "Carlito's Way"
}


failed_movies = [] 

for idx, movie_title in enumerate(top_500_titles, 1):
    corrected_title = title_corrections.get(movie_title, movie_title)  #we now apply corrections wherever applicable

    print(f"Fetching {idx}/{len(top_500_titles)}: {corrected_title}")
    data = fetch_movie_data(corrected_title)
    
    if data:
        movie_data.append(data)
    else:
        failed_movies.append(corrected_title)
    
    time.sleep(0.5)

df = pd.DataFrame(movie_data)
df.to_csv("imdb_top500_omdb.csv", index=False)

print("✅ Successfully saved imdb_top500_omdb.csv!")
# Out:
# Fetching 1/500: The Godfather
# Fetching 2/500: The Godfather Part Ii
# Fetching 3/500: Seven Samurai
# Fetching 4/500: 12 Angry Men
# Fetching 5/500: City Lights
# Fetching 6/500: The Good The Bad And The Ugly
# Fetching 7/500: The Shawshank Redemption
# Fetching 8/500: Psycho
# Fetching 9/500: Modern Times
# Fetching 10/500: Schindler's List
# Fetching 11/500: Pulp Fiction
# Fetching 12/500: Rear Window
# Fetching 13/500: One Flew Over the Cuckoo's Nest
# Fetching 14/500: Apocalypse Now
# Fetching 15/500: Tokyo Story
# Fetching 16/500: Spirited Away
# Fetching 17/500: Goodfellas
# Fetching 18/500: Vertigo
# Fetching 19/500: Singin In The Rain
# Fetching 20/500: Sunset Boulevard
# Fetching 21/500: Citizen Kane
# Fetching 22/500: Harakiri
# Fetching 23/500: Rashomon
# Fetching 24/500: Once Upon A Time In The West
# Fetching 25/500: Fanny And Alexander
# Fetching 26/500: The Lord Of The Rings The Return Of The King
# Fetching 27/500: Andrei Rublev
# Fetching 28/500: The Passion Of Joan Of Arc
# Fetching 29/500: Sherlock Jr
# Fetching 30/500: Bicycle Thieves
# Fetching 31/500: Casablanca
# Fetching 32/500: Some Like It Hot
# Fetching 33/500: Persona
# Fetching 34/500: Children Of Paradise
# Fetching 35/500: Taxi Driver
# Fetching 36/500: The Dark Knight
# Fetching 37/500: Metropolis
# Fetching 38/500: Sunrise: A Song of Two Humans
# ❗ Movie not found: Sunrise: A Song of Two Humans
# Fetching 39/500: Stalker
# Fetching 40/500: Pather Panchali
# Fetching 41/500: Lawrence Of Arabia
# Fetching 42/500: M
# Fetching 43/500: Ordet
# Fetching 44/500: It's a Wonderful Life
# Fetching 45/500: Satantango
# Fetching 46/500: Parasite 2019
# Fetching 47/500: The 400 Blows
# Fetching 48/500: Ikiru
# Fetching 49/500: Mirror
# Fetching 50/500: Come And See
# Fetching 51/500: The Apartment
# Fetching 52/500: The General
# Fetching 53/500: Grave Of The Fireflies
# Fetching 54/500: Le Trou
# Fetching 55/500: The Battle Of Algiers
# Fetching 56/500: A Man Escaped
# Fetching 57/500: Dr Strangelove Or How I Learned To Stop Worrying And Love The Bomb
# Fetching 58/500: Paths Of Glory
# Fetching 59/500: The Lord Of The Rings The Fellowship Of The Ring
# Fetching 60/500: All About Eve
# Fetching 61/500: The Empire Strikes Back
# Fetching 62/500: High And Low
# Fetching 63/500: The Great Dictator
# Fetching 64/500: The Silence Of The Lambs
# Fetching 65/500: 2001 A Space Odyssey
# Fetching 66/500: North By Northwest
# Fetching 67/500: Double Indemnity
# Fetching 68/500: Ugetsu
# Fetching 69/500: Woman In The Dunes
# Fetching 70/500: Sansho The Bailiff
# Fetching 71/500: Once Upon A Time In America
# Fetching 72/500: City Of God
# Fetching 73/500: Late Spring
# Fetching 74/500: Barry Lyndon
# Fetching 75/500: The Lord Of The Rings The Two Towers
# Fetching 76/500: Raging Bull
# Fetching 77/500: Chinatown
# Fetching 78/500: Alien
# Fetching 79/500: Ran
# Fetching 80/500: The Seventh Seal
# Fetching 81/500: The Kid
# Fetching 82/500: Wild Strawberries
# Fetching 83/500: A Brighter Summer Day
# Fetching 84/500: 8½
# Fetching 85/500: The Pianist
# Fetching 86/500: The World of Apu
# Fetching 87/500: La Dolce Vita
# Fetching 88/500: Star Wars
# Fetching 89/500: The Best Of Youth
# Fetching 90/500: The Gold Rush
# Fetching 91/500: The Third Man
# Fetching 92/500: The Treasure Of The Sierra Madre
# Fetching 93/500: I Am Cuba
# Fetching 94/500: The Lives Of Others
# Fetching 95/500: Witness for the Prosecution
# Fetching 96/500: Touch Of Evil
# Fetching 97/500: WALL·E
# Fetching 98/500: Scenes From A Marriage
# Fetching 99/500: To Be Or Not To Be
# Fetching 100/500: A Separation
# Fetching 101/500: The Night Of The Hunter
# Fetching 102/500: Three Colors: Red
# Fetching 103/500: Yojimbo
# Fetching 104/500: Back To The Future
# Fetching 105/500: My Neighbor Totoro
# Fetching 106/500: In The Mood For Love
# Fetching 107/500: Princess Mononoke
# Fetching 108/500: Saving Private Ryan
# Fetching 109/500: Cinema Paradiso
# Fetching 110/500: La Jetee
# Fetching 111/500: The Wages Of Fear
# Fetching 112/500: Das Boot
# Fetching 113/500: Fight Club
# Fetching 114/500: Nights Of Cabiria
# Fetching 115/500: La Strada
# Fetching 116/500: Amadeus
# Fetching 117/500: Forrest Gump
# Fetching 118/500: Spider Man Into The Spider Verse
# Fetching 119/500: The Lion King
# Fetching 120/500: Inception
# Fetching 121/500: Whiplash 2014
# Fetching 122/500: The Shop Around The Corner
# Fetching 123/500: Rififi
# Fetching 124/500: Umberto D
# Fetching 125/500: Army Of Shadows
# Fetching 126/500: Blade Runner
# Fetching 127/500: Samurai Rebellion
# Fetching 128/500: Close Up
# Fetching 129/500: The Circus
# Fetching 130/500: Raiders Of The Lost Ark
# Fetching 131/500: Grand Illusion
# Fetching 132/500: A Clockwork Orange
# Fetching 133/500: Eternal Sunshine Of The Spotless Mind
# Fetching 134/500: A Woman Under The Influence
# Fetching 135/500: The Cranes Are Flying
# Fetching 136/500: Yi Yi
# Fetching 137/500: To Kill A Mockingbird
# Fetching 138/500: The Matrix
# Fetching 139/500: The Sting
# Fetching 140/500: The Mother And The Whore
# Fetching 141/500: Se7En
# Fetching 142/500: Early Summer
# Fetching 143/500: Werckmeister Harmonies
# Fetching 144/500: Coco
# Fetching 145/500: Toy Story
# Fetching 146/500: It Happened One Night
# Fetching 147/500: Reservoir Dogs
# Fetching 148/500: Unforgiven
# Fetching 149/500: The Deer Hunter
# Fetching 150/500: The Young And The Damned
# Fetching 151/500: The Best Years Of Our Lives
# Fetching 152/500: The Leopard
# Fetching 153/500: Time Of The Gypsies
# Fetching 154/500: Ali Fear Eats The Soul
# Fetching 155/500: Raise The Red Lantern
# Fetching 156/500: Terminator 2 Judgment Day
# Fetching 157/500: The Shining
# Fetching 158/500: Portrait Of A Lady On Fire
# Fetching 159/500: Viridiana
# Fetching 160/500: Greed
# Fetching 161/500: Gone With The Wind
# Fetching 162/500: There Will Be Blood
# Fetching 163/500: La Confidential
# Fetching 164/500: Paris Texas
# Fetching 165/500: Throne Of Blood
# Fetching 166/500: Toy Story 3
# Fetching 167/500: Memento
# Fetching 168/500: On The Waterfront
# Fetching 169/500: A Trip To The Moon
# Fetching 170/500: The Rules Of The Game
# Fetching 171/500: Red Beard
# Fetching 172/500: The Grapes Of Wrath
# Fetching 173/500: Au Hasard Balthazar
# Fetching 174/500: Autumn Sonata
# Fetching 175/500: Annie Hall
# Fetching 176/500: The Conformist
# Fetching 177/500: Rocco And His Brothers
# Fetching 178/500: Dersu Uzala
# Fetching 179/500: Cool Hand Luke
# Fetching 180/500: Monty Python And The Holy Grail
# Fetching 181/500: Le Samourai
# Fetching 182/500: Aliens
# Fetching 183/500: Playtime
# Fetching 184/500: The Bridge On The River Kwai
# Fetching 185/500: The Red Shoes
# Fetching 186/500: American Beauty
# Fetching 187/500: To Live
# Fetching 188/500: Battleship Potemkin
# Fetching 189/500: Day Of Wrath
# Fetching 190/500: All Quiet On The Western Front
# Fetching 191/500: It's Such a Beautiful Day
# Fetching 192/500: Full Metal Jacket
# Fetching 193/500: The Cabinet of Dr. Caligari
# Fetching 194/500: Kes
# Fetching 195/500: The Usual Suspects
# Fetching 196/500: The Cameraman
# Fetching 197/500: Aparajito
# Fetching 198/500: The Elephant Man
# Fetching 199/500: Rebecca
# Fetching 200/500: Make Way For Tomorrow
# Fetching 201/500: The Great Escape
# Fetching 202/500: Your Name
# Fetching 203/500: Limelight
# Fetching 204/500: Breathless
# Fetching 205/500: Underground
# Fetching 206/500: The Man Who Shot Liberty Valance
# Fetching 207/500: Aguirre The Wrath Of God
# Fetching 208/500: Oldboy
# Fetching 209/500: Up
# Fetching 210/500: Anatomy Of A Murder
# Fetching 211/500: The Wild Bunch
# Fetching 212/500: The Hunt 2012
# Fetching 213/500: Il Sorpasso
# Fetching 214/500: The Last Laugh
# Fetching 215/500: A Streetcar Named Desire
# Fetching 216/500: Life Is Beautiful
# Fetching 217/500: A Short Film About Love
# Fetching 218/500: The Shop On Main Street
# Fetching 219/500: Rio Bravo
# Fetching 220/500: Roman Holiday
# Fetching 221/500: Ivan's Childhood
# Fetching 222/500: The Exterminating Angel
# Fetching 223/500: Trainspotting
# Fetching 224/500: The Last Picture Show
# Fetching 225/500: The Truman Show
# Fetching 226/500: Memories Of Murder
# Fetching 227/500: Faust
# Fetching 228/500: Sans Soleil
# Fetching 229/500: Song Of The Sea
# Fetching 230/500: Leon The Professional
# Fetching 231/500: Fargo
# Fetching 232/500: Solaris
# Fetching 233/500: Sweet Smell Of Success
# Fetching 234/500: For A Few Dollars More
# Fetching 235/500: White Heat
# Fetching 236/500: Brief Encounter
# Fetching 237/500: Wings Of Desire
# Fetching 238/500: Les Diaboliques
# Fetching 239/500: An Autumn Afternoon
# Fetching 240/500: The Tale Of The Princess Kaguya
# Fetching 241/500: Amarcord
# Fetching 242/500: Heat 1995
# Fetching 243/500: L'Atalante
# Fetching 244/500: Django Unchained
# Fetching 245/500: Jeanne Dielman 23 Quai Du Commerce 1080 Bruxelles
# Fetching 246/500: Kind Hearts And Coronets
# Fetching 247/500: Dog Day Afternoon
# Fetching 248/500: Forbidden Games
# Fetching 249/500: The Crowd
# Fetching 250/500: Notorious
# Fetching 251/500: Mary And Max
# Fetching 252/500: Persepolis
# Fetching 253/500: Howl's Moving Castle
# Fetching 254/500: Nausicaa Of The Valley Of The Wind
# Fetching 255/500: Safety Last
# Fetching 256/500: Rosemary's Baby
# Fetching 257/500: L'Avventura
# Fetching 258/500: The Searchers
# Fetching 259/500: La Haine
# Fetching 260/500: Three Colors: Blue
# Fetching 261/500: Chungking Express
# Fetching 262/500: Inside Out
# Fetching 263/500: Where Is My Friend's House?
# ❗ Movie not found: Where Is My Friend's House?
# Fetching 264/500: Cries And Whispers
# Fetching 265/500: Napoleon
# Fetching 266/500: Paper Moon
# Fetching 267/500: The Spirit Of The Beehive
# Fetching 268/500: A Special Day
# Fetching 269/500: Nostalghia
# Fetching 270/500: Network
# Fetching 271/500: L'Eclisse
# Fetching 272/500: Mr Smith Goes To Washington
# Fetching 273/500: Sanjuro
# Fetching 274/500: Badlands
# Fetching 275/500: Vivre Sa Vie
# Fetching 276/500: Nobody Knows
# Fetching 277/500: No Country For Old Men
# Fetching 278/500: Spring Summer Fall Winter And Spring
# Fetching 279/500: La Notte
# Fetching 280/500: The Celebration
# Fetching 281/500: In the Name of the Father
# Fetching 282/500: I Am A Fugitive From A Chain Gang
# Fetching 283/500: Shoplifters
# Fetching 284/500: Finding Nemo
# Fetching 285/500: Z
# Fetching 286/500: The Phantom Carriage
# Fetching 287/500: Manhattan
# Fetching 288/500: Rome Open City
# Fetching 289/500: Children Of Heaven
# Fetching 290/500: The Green Mile
# Fetching 291/500: The Iron Giant
# Fetching 292/500: The Sacrifice
# Fetching 293/500: The Philadelphia Story
# Fetching 294/500: The Twilight Samurai
# Fetching 295/500: Before Sunset
# Fetching 296/500: Before Sunrise
# Fetching 297/500: Castle In The Sky
# Fetching 298/500: The Departed
# Fetching 299/500: Brazil
# Fetching 300/500: Incendies
# Fetching 301/500: The Maltese Falcon
# Fetching 302/500: The Wizard Of Oz 1939
# Fetching 303/500: Le Cercle Rouge
# Fetching 304/500: Monsieur Verdoux
# Fetching 305/500: The Return
# Fetching 306/500: Secrets Lies
# Fetching 307/500: The Hidden Fortress
# Fetching 308/500: Pan's Labyrinth
# Fetching 309/500: Amelie
# Fetching 310/500: Ben-Hur
# Fetching 311/500: Fitzcarraldo
# Fetching 312/500: American History X
# Fetching 313/500: Ace In The Hole
# Fetching 314/500: Capernaum
# Fetching 315/500: Still Walking
# Fetching 316/500: All About My Mother
# Fetching 317/500: The Discreet Charm Of The Bourgeoisie
# Fetching 318/500: Platoon
# Fetching 319/500: Farewell My Concubine
# Fetching 320/500: Letter From An Unknown Woman
# Fetching 321/500: The Grand Budapest Hotel
# Fetching 322/500: The Virgin Spring
# Fetching 323/500: The Red Balloon
# Fetching 324/500: Stagecoach
# Fetching 325/500: Mulholland Drive
# Fetching 326/500: A Matter Of Life And Death
# Fetching 327/500: High Noon
# Fetching 328/500: Orpheus
# Fetching 329/500: Life Of Brian
# Fetching 330/500: Casino
# Fetching 331/500: Kagemusha
# Fetching 332/500: Butch Cassidy And The Sundance Kid
# Fetching 333/500: In A Lonely Place
# Fetching 334/500: Scarface 1983
# Fetching 335/500: A Short Film About Killing
# Fetching 336/500: Room 2015
# Fetching 337/500: Beauty And The Beast
# Fetching 338/500: The Hustler
# Fetching 339/500: Cleo From 5 To 7
# Fetching 340/500: Hana-bi
# ❗ Movie not found: Hana-bi
# Fetching 341/500: Mad Max Fury Road
# Fetching 342/500: Steamboat Bill Jr
# Fetching 343/500: Judgment At Nuremberg
# Fetching 344/500: The Straight Story
# Fetching 345/500: Meshes Of The Afternoon
# Fetching 346/500: Alice In The Cities
# Fetching 347/500: Akira
# Fetching 348/500: Good Will Hunting
# Fetching 349/500: The Miracle Worker
# Fetching 350/500: Talk To Her
# Fetching 351/500: The Graduate
# Fetching 352/500: Beauty And The Beast 1991
# Fetching 353/500: The Heiress
# Fetching 354/500: Fantasia
# Fetching 355/500: Au Revoir Les Enfants
# Fetching 356/500: Three Billboards Outside Ebbing Missouri
# Fetching 357/500: Inglourious Basterds
# Fetching 358/500: Elevator To The Gallows
# Fetching 359/500: Gladiator 2000
# Fetching 360/500: Through A Glass Darkly
# Fetching 361/500: Million Dollar Baby
# Fetching 362/500: Days Of Heaven
# Fetching 363/500: Do The Right Thing
# Fetching 364/500: Out Of The Past
# Fetching 365/500: Strangers On A Train
# Fetching 366/500: Blue Velvet
# Fetching 367/500: That Obscure Object Of Desire
# Fetching 368/500: What Ever Happened To Baby Jane
# Fetching 369/500: My Night at Maud's
# Fetching 370/500: The Earrings Of Madame De
# Fetching 371/500: The Conversation
# Fetching 372/500: Marriage Story
# Fetching 373/500: The Killing
# Fetching 374/500: The Servant
# Fetching 375/500: The Intouchables
# Fetching 376/500: The Life And Death Of Colonel Blimp
# Fetching 377/500: Jaws
# Fetching 378/500: Winter Light
# Fetching 379/500: Love Exposure
# Fetching 380/500: Hiroshima Mon Amour
# Fetching 381/500: Day For Night
# Fetching 382/500: Ratatouille
# Fetching 383/500: Ghost In The Shell
# Fetching 384/500: Germany Year Zero
# Fetching 385/500: Spotlight
# Fetching 386/500: Die Hard
# Fetching 387/500: Laura
# Fetching 388/500: Sleuth
# Fetching 389/500: The Diving Bell And The Butterfly
# Fetching 390/500: The Handmaiden
# Fetching 391/500: Stand By Me
# Fetching 392/500: Wolf Children
# Fetching 393/500: Shoeshine
# Fetching 394/500: Freaks
# Fetching 395/500: Nosferatu
# Fetching 396/500: Dial M For Murder
# Fetching 397/500: Amour
# Fetching 398/500: 12 Years A Slave
# Fetching 399/500: The Nightmare Before Christmas
# Fetching 400/500: Cabaret
# Fetching 401/500: Central Station
# Fetching 402/500: Landscape In The Mist
# Fetching 403/500: 1917
# Fetching 404/500: Intolerance: Love's Struggle Throughout the Ages
# ❗ Movie not found: Intolerance: Love's Struggle Throughout the Ages
# Fetching 405/500: Call Me By Your Name
# Fetching 406/500: Midnight Cowboy
# Fetching 407/500: Shadow Of A Doubt
# Fetching 408/500: Interstellar
# Fetching 409/500: Hannah And Her Sisters
# Fetching 410/500: Monsters Inc
# Fetching 411/500: The Testament Of Dr Mabuse
# Fetching 412/500: Downfall
# Fetching 413/500: Being There
# Fetching 414/500: The Killer
# Fetching 415/500: My Left Foot
# Fetching 416/500: Jean De Florette
# Fetching 417/500: The Big Lebowski
# Fetching 418/500: The King's Speech
# Fetching 419/500: Whisper Of The Heart
# Fetching 420/500: Et The Extra Terrestrial
# Fetching 421/500: Infernal Affairs
# Fetching 422/500: The Prestige
# Fetching 423/500: Our Hospitality
# Fetching 424/500: Zootopia
# Fetching 425/500: Toy Story 2
# Fetching 426/500: Klaus
# Fetching 427/500: The Big Sleep
# Fetching 428/500: Ford V Ferrari
# Fetching 429/500: Dead Poets Society
# Fetching 430/500: The Terminator
# Fetching 431/500: Naked
# Fetching 432/500: Dangal
# Fetching 433/500: Kwaidan
# Fetching 434/500: The Man Who Would Be King
# Fetching 435/500: Wild Tales
# Fetching 436/500: Groundhog Day
# Fetching 437/500: Catch Me If You Can 2002
# Fetching 438/500: I Vitelloni
# Fetching 439/500: The Big Heat
# Fetching 440/500: The Double Life Of Veronique
# Fetching 441/500: Who's Afraid of Virginia Woolf?
# Fetching 442/500: Requiem For A Dream
# Fetching 443/500: Rope
# Fetching 444/500: Love And Death
# Fetching 445/500: The Remains Of The Day
# Fetching 446/500: Jules And Jim
# Fetching 447/500: The Gospel According to St. Matthew
# Fetching 448/500: How To Train Your Dragon
# Fetching 449/500: Harry Potter And The Deathly Hallows Part 2
# Fetching 450/500: Cat On A Hot Tin Roof
# Fetching 451/500: The French Connection
# Fetching 452/500: Opening Night
# Fetching 453/500: Hotel Rwanda
# Fetching 454/500: 4 Months 3 Weeks And 2 Days
# Fetching 455/500: Tampopo
# Fetching 456/500: Scarface
# Fetching 457/500: The Face Of Another
# Fetching 458/500: The Roaring Twenties
# Fetching 459/500: Pickpocket
# Fetching 460/500: Kiki's Delivery Service
# Fetching 461/500: A Prophet
# Fetching 462/500: Zelig
# Fetching 463/500: Trouble In Paradise
# Fetching 464/500: Gran Torino
# Fetching 465/500: Last Year At Marienbad
# Fetching 466/500: All the President's Men
# Fetching 467/500: Breaking The Waves
# Fetching 468/500: Indiana Jones And The Last Crusade
# Fetching 469/500: Divorce Italian Style
# Fetching 470/500: Edward Scissorhands
# Fetching 471/500: The Thing
# Fetching 472/500: Perfect Blue
# Fetching 473/500: Down By Law
# Fetching 474/500: Bringing Up Baby
# Fetching 475/500: The Phantom Of Liberty
# Fetching 476/500: Bonnie And Clyde
# Fetching 477/500: The Incredibles
# Fetching 478/500: Rocky
# Fetching 479/500: His Girl Friday
# Fetching 480/500: Mommy
# Fetching 481/500: Mon Oncle
# Fetching 482/500: My Fair Lady
# Fetching 483/500: Charade
# Fetching 484/500: Stalag 17
# Fetching 485/500: Boyhood
# Fetching 486/500: The Secret In Their Eyes
# Fetching 487/500: Ninotchka
# Fetching 488/500: Pierrot Le Fou
# Fetching 489/500: The Enigma Of Kaspar Hauser
# Fetching 490/500: Stroszek
# Fetching 491/500: A Hard Day's Night
# Fetching 492/500: Onibaba
# Fetching 493/500: Repulsion
# Fetching 494/500: Like Stars On Earth
# Fetching 495/500: Duck Soup
# Fetching 496/500: Carlito's Way
# Fetching 497/500: Nashville
# Fetching 498/500: The Triplets Of Belleville
# Fetching 499/500: Dr Mabuse The Gambler
# Fetching 500/500: Gone Girl
# ✅ Successfully saved imdb_top500_omdb.csv!

# %% [markdown]
# ## Data Load

# %%
df = pd.read_csv('/Users/janhavisharma/Desktop/MSDS/2 SEM 2/Data Wrangling/Project/New/imdb_top500_omdb.csv')

# %%
#find number of missing values/column
missing_values_per_column = df.isnull().sum()
print(missing_values_per_column)
# Out:
# Title            0
# Year             0
# Rated           26
# Runtime         16
# Genre            7
# Director        19
# Stars           13
# IMDb_Rating     20
# Metascore      139
# Votes           19
# Gross          166
# Plot            18
# dtype: int64

# %%
#Data Imputation:
#step 1:
duplicate_rows = df[df.duplicated()]
print("✅ Duplicate rows found:")
print(duplicate_rows)

#step 2:
print(f"\nNumber of duplicate rows: {duplicate_rows.shape[0]}")

duplicate_indices = df[df.duplicated()].index.tolist()
print(f"\nIndices of duplicate rows: {duplicate_indices}")


# df_cleaned = df_without_plot.drop_duplicates()
# df_cleaned.to_csv('imdb_top500_omdb_cleaned.csv', index=False)
# Out:
# ✅ Duplicate rows found:
# Empty DataFrame
# Columns: [Title, Year, Rated, Runtime, Genre, Director, Stars, IMDb_Rating, Metascore, Votes, Gross, Plot]
# Index: []
#
# Number of duplicate rows: 0
#
# Indices of duplicate rows: []

# %%
#Dropping 'Plot' col
df_without_plot = df.drop(columns=['Plot'])

#check for duplicate titles
duplicate_titles = df[df.duplicated(subset='Title', keep=False)]
print(duplicate_titles)

print(f"\nNumber of duplicate Titles: {duplicate_titles['Title'].nunique()}")
# Out:
# Empty DataFrame
# Columns: [Title, Year, Rated, Runtime, Genre, Director, Stars, IMDb_Rating, Metascore, Votes, Gross, Plot]
# Index: []
#
# Number of duplicate Titles: 0

# %%
df_without_plot
# Out:
#                           Title  Year      Rated  Runtime  \
# 0                 The Godfather  1972          R  175 min
# 1         The Godfather Part II  1974          R  202 min
# 2                 Seven Samurai  1954  Not Rated  207 min
# 3                  12 Angry Men  1957   Approved   96 min
# 4                   City Lights  1931          G   87 min
# ..                          ...   ...        ...      ...
# 491               Carlito's Way  1993          R  144 min
# 492                   Nashville  1975          R  160 min
# 493  The Triplets of Belleville  2003      PG-13   80 min
# 494     Dr. Mabuse, the Gambler  1922  Not Rated  242 min
# 495                   Gone Girl  2014          R  149 min
#
#                             Genre              Director  \
# 0                    Crime, Drama  Francis Ford Coppola
# 1                    Crime, Drama  Francis Ford Coppola
# 2                   Action, Drama        Akira Kurosawa
# 3                    Crime, Drama          Sidney Lumet
# 4          Comedy, Drama, Romance       Charles Chaplin
# ..                            ...                   ...
# 491        Crime, Drama, Thriller        Brian De Palma
# 492          Comedy, Drama, Music         Robert Altman
# 493  Animation, Adventure, Comedy        Sylvain Chomet
# 494      Crime, Mystery, Thriller            Fritz Lang
# 495      Drama, Mystery, Thriller         David Fincher
#
#                                                  Stars  IMDb_Rating  \
# 0                 Marlon Brando, Al Pacino, James Caan          9.2
# 1             Al Pacino, Robert De Niro, Robert Duvall          9.0
# 2      Toshirô Mifune, Takashi Shimura, Keiko Tsushima          8.6
# 3              Henry Fonda, Lee J. Cobb, Martin Balsam          9.0
# 4     Charles Chaplin, Virginia Cherrill, Florence Lee          8.5
# ..                                                 ...          ...
# 491          Al Pacino, Sean Penn, Penelope Ann Miller          7.9
# 492        Keith Carradine, Karen Black, Ronee Blakley          7.6
# 493  Michèle Caucheteux, Jean-Claude Donda, Michel ...          7.7
# 494  Rudolf Klein-Rogge, Aud Egede-Nissen, Gertrude...          7.8
# 495    Ben Affleck, Rosamund Pike, Neil Patrick Harris          8.1
#
#      Metascore      Votes         Gross
# 0        100.0  2,108,592  $136,381,073
# 1         90.0  1,424,468   $47,834,595
# 2         98.0    379,094      $820,278
# 3         97.0    920,922           NaN
# 4         99.0    205,485       $19,181
# ..         ...        ...           ...
# 491       66.0    239,534   $36,948,322
# 492       96.0     29,372    $9,984,123
# 493       91.0     57,843    $7,007,149
# 494        NaN      9,382           NaN
# 495       79.0  1,104,943  $167,767,189
#
# [496 rows x 11 columns]

# %%
#fill missing values in 'Gross' column with 'No info' in df_without_plot
df_without_plot['Gross'] = df_without_plot['Gross'].fillna('No info')
print(df_without_plot['Gross'].isnull().sum())
print(df_without_plot[['Title', 'Gross']].head(25))
# Out:
# 0
#                               Title         Gross
# 0                     The Godfather  $136,381,073
# 1             The Godfather Part II   $47,834,595
# 2                     Seven Samurai      $820,278
# 3                      12 Angry Men       No info
# 4                       City Lights       $19,181
# 5    The Good, the Bad and the Ugly   $25,100,000
# 6          The Shawshank Redemption   $28,767,189
# 7                            Psycho   $32,000,000
# 8                      Modern Times      $163,577
# 9                  Schindler's List   $96,898,818
# 10                     Pulp Fiction  $107,928,762
# 11                      Rear Window   $36,764,313
# 12  One Flew Over the Cuckoo's Nest  $108,981,275
# 13                   Apocalypse Now   $96,042,913
# 14                      Tokyo Story       No info
# 15                    Spirited Away   $15,205,725
# 16                       Goodfellas   $46,909,721
# 17                          Vertigo    $7,863,310
# 18              Singin' in the Rain    $1,884,537
# 19                 Sunset Boulevard      $299,645
# 20                     Citizen Kane    $1,627,530
# 21                         Harakiri       No info
# 22                         Rashomon       $46,808
# 23     Once Upon a Time in the West    $5,321,508
# 24              Fanny and Alexander    $6,783,304

# %% [markdown]
# ## Data Storage Techniques

# %% [markdown]
# #### Method-1

# %%
df_without_plot.to_csv('cleaned_data.csv', index=False)

# %% [markdown]
# #### Method-2

# %%
df_without_plot.to_excel('movies_cleaned.xlsx', index=False)

# %% [markdown]
# #### Method-3

# %%
import sqlite3

# %%
conn = sqlite3.connect('movies_cleaned.db')

# %%
df_without_plot.to_sql('movies', conn, index=False, if_exists='replace')
# Out:
# 496

# %%
conn.close()

# %% [markdown]
# #### We'll be performing EDA on this csv.
